# %%
print("my name is {} and I'm {}".format("depi",20))
# Out:
# my name is depi and I'm 20

# %%
your_name="aya"
your_age=20
course_name="AI"
print(f"My name is {your_name},and I am {your_age} years old. I am engaged in learning {course_name}")
# Out:
# My name is aya,and I am 20 years old. I am engaged in learning AI

# %%
name="depi learning"
name.upper()
# Out:
# 'DEPI LEARNING'

# %%
list_one=[1,2,3,4,"depi","true",[10,11,12,["m1","m2","m3",True]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
list_one1=[1,2,3,"machine"]
list_one1.append("learning")
print(list_one1)
# Out:
# [1, 2, 3, 'machine', 'learning']

# %%
list_one1=[1,2,3,"machine"]
list_one1.insert(0,"DEPI")
print(list_one1)
# Out:
# ['DEPI', 1, 2, 3, 'machine']

# %%
list_one1=[1,2,3,"machine"]
list_one1.extend("learning")
print(list_one1)
# Out:
# [1, 2, 3, 'machine', 'l', 'e', 'a', 'r', 'n', 'i', 'n', 'g']

# %%
list_one1=[1,2,3,"machine"]
list_one1.remove(2)
print(list_one1)
# Out:
# [1, 3, 'machine']
